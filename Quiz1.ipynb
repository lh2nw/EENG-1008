# %% [markdown]
# <a href="https://colab.research.google.com/github/lh2nw/EENG-1008/blob/main/Quiz1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("This is a quiz")
# Out:
# This is a quiz

# %%
x=float(input("Score: "))
if x>=93:
    grade = "A"
elif x>=90:
    grade = "A-"
elif x>=87:
    grade = "B+"
elif x>=83:
    grade = "B"
elif x>=80:
    grade = "B-"
elif x>=77:
    grade = "C+"
elif x>=73:
    grade = "C"
elif x>=70:
    grade = "C-"
elif x>=67:
    grade = "D+"
elif x>=63:
    grade = "D"
elif x>=60:
    grade = "D-"
else:
    grade = "F"
print (grade)
# Out:
# Score: 89
# B+
